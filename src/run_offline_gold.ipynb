# %% [markdown]
# ## Run experiments on remote server offline
#
# It saves the results in the results folder.

# %%
import sys

class redirect_output(object):
    """context manager for reditrecting stdout/err to files"""


    def __init__(self, stdout='', stderr=''):
        self.stdout = stdout
        self.stderr = stderr

    def __enter__(self):
        self.sys_stdout = sys.stdout
        self.sys_stderr = sys.stderr

        if self.stdout:
            sys.stdout = open(self.stdout, 'w')
        if self.stderr:
            if self.stderr == self.stdout:
                sys.stderr = sys.stdout
            else:
                sys.stderr = open(self.stderr, 'w')

    def __exit__(self, exc_type, exc_value, traceback):
        sys.stdout = self.sys_stdout
        sys.stderr = self.sys_stderr

# %% [markdown]
# First we run only fonduer without using the cell annotation in the code.
# Rule-base

# %%
with redirect_output("results/troy200_fonduer_annotations_gold.txt"):
    # %run "./troy200_fonduer_annotations_gold.ipynb"
# Out:
# [2020-06-07 09:13:15,690][INFO] fonduer.meta:51 - Setting logging directory to: logs/2020-06-07_09-13-15
# [2020-06-07 09:13:15,732][INFO] fonduer.meta:135 - Connecting user:user to postgres:5432/troy200_col_row_data
# [2020-06-07 09:13:16,494][INFO] fonduer.meta:162 - Initializing the storage schema
# [2020-06-07 09:13:18,772][INFO] fonduer.candidates.candidates:145 - Clearing table row_candidate (split 0)
# [2020-06-07 09:13:18,777][INFO] fonduer.utils.udf:69 - Running UDF...
# ...
# Process CandidateExtractorUDF-5:
# Traceback (most recent call last):
# Process CandidateExtractorUDF-9:
#   File "/usr/local/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/utils/udf.py", line 207, in run
#     y = self.apply(doc, **self.apply_kwargs)
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/candidates/candidates.py", line 295, in apply
# ...
