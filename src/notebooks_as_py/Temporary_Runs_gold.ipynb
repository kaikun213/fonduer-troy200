# %% [markdown]
# ## Run experiments on remote server offline
#
# It saves the results in the results folder.

# %%
import sys

class redirect_output(object):
    """context manager for reditrecting stdout/err to files"""


    def __init__(self, stdout='', stderr=''):
        self.stdout = stdout
        self.stderr = stderr

    def __enter__(self):
        self.sys_stdout = sys.stdout
        self.sys_stderr = sys.stderr

        if self.stdout:
            sys.stdout = open(self.stdout, 'w')
        if self.stderr:
            if self.stderr == self.stdout:
                sys.stderr = sys.stdout
            else:
                sys.stderr = open(self.stderr, 'w')

    def __exit__(self, exc_type, exc_value, traceback):
        sys.stdout = self.sys_stdout
        sys.stderr = self.sys_stderr

# %% [markdown]
# First we run only fonduer without using the cell annotation in the code.
# Rule-base

# %%
with redirect_output("results/troy200_fonduer.txt"):
    # %run "./troy200_fonduer.py"
# Out:
# [2020-06-06 11:25:51,078][INFO] fonduer.meta:51 - Setting logging directory to: logs/2020-06-06_11-25-51
# [2020-06-06 11:25:51,125][INFO] fonduer.meta:135 - Connecting user:user to postgres:5432/troy200_col_row_data
# [2020-06-06 11:25:51,940][INFO] fonduer.meta:162 - Initializing the storage schema
# [2020-06-06 11:25:56,836][INFO] fonduer.utils.udf:69 - Running UDF...
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# [2020-06-06 11:26:59,695][INFO] fonduer.candidates.mentions:473 - Clearing table: data
# [2020-06-06 11:26:59,701][INFO] fonduer.candidates.mentions:473 - Clearing table: row
# [2020-06-06 11:26:59,706][INFO] fonduer.candidates.mentions:473 - Clearing table: col
# [2020-06-06 11:26:59,711][INFO] fonduer.utils.udf:69 - Running UDF...
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# [2020-06-06 11:27:46,084][INFO] fonduer.candidates.candidates:145 - Clearing table row_candidate (split 0)
# [2020-06-06 11:27:46,370][INFO] fonduer.utils.udf:69 - Running UDF...
# HBox(children=(FloatProgress(value=0.0, max=160.0), HTML(value='')))
# Process CandidateExtractorUDF-20:
# Process CandidateExtractorUDF-24:
# Process CandidateExtractorUDF-21:
# Process CandidateExtractorUDF-22:
# Process CandidateExtractorUDF-26:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process CandidateExtractorUDF-27:
#   File "/usr/local/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/utils/udf.py", line 207, in run
#     y = self.apply(doc, **self.apply_kwargs)
#   File "/usr/local/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/utils/udf.py", line 207, in run
#     y = self.apply(doc, **self.apply_kwargs)
# Traceback (most recent call last):
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/candidates/candidates.py", line 295, in apply
#     tuple(cand[j][1] for j in range(self.arities[i]))
# Traceback (most recent call last):
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/utils/udf.py", line 207, in run
#     y = self.apply(doc, **self.apply_kwargs)
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/candidates/candidates.py", line 295, in apply
#     tuple(cand[j][1] for j in range(self.arities[i]))
# Process CandidateExtractorUDF-25:
#   File "/home/user/src/notebooks_as_py/troy200_fonduer.py", line 256, in row_filter
#     if same_table((data, row)):
#   File "/usr/local/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Exception ignored in: <bound method InstanceState._cleanup of <sqlalchemy.orm.state.InstanceState object at 0x7fb414b9f090>>
#   File "/usr/local/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/candidates/candidates.py", line 281, in apply
#     for mention in candidate_class.mentions
#   File "/home/user/src/notebooks_as_py/troy200_fonduer.py", line 256, in row_filter
#     if same_table((data, row)):
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/utils/udf.py", line 207, in run
#     y = self.apply(doc, **self.apply_kwargs)
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/utils/data_model_utils/tabular.py", line 35, in same_table
#     for i in range(len(c))
# Traceback (most recent call last):
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/utils/udf.py", line 207, in run
#     y = self.apply(doc, **self.apply_kwargs)
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/candidates/candidates.py", line 281, in <listcomp>
#     for mention in candidate_class.mentions
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/utils/data_model_utils/tabular.py", line 35, in same_table
#     for i in range(len(c))
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/utils/data_model_utils/tabular.py", line 35, in <genexpr>
#     for i in range(len(c))
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/candidates/candidates.py", line 295, in apply
#     tuple(cand[j][1] for j in range(self.arities[i]))
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/state.py", line 371, in _cleanup
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/candidates/candidates.py", line 295, in apply
#     tuple(cand[j][1] for j in range(self.arities[i]))
# Traceback (most recent call last):
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/attributes.py", line 286, in __get__
#     return self.impl.get(instance_state(instance), dict_)
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/utils/data_model_utils/tabular.py", line 35, in <genexpr>
#     for i in range(len(c))
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/attributes.py", line 286, in __get__
#     return self.impl.get(instance_state(instance), dict_)
#   File "/home/user/src/notebooks_as_py/troy200_fonduer.py", line 256, in row_filter
#     if same_table((data, row)):
#   File "/usr/local/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/user/src/notebooks_as_py/troy200_fonduer.py", line 256, in row_filter
#     if same_table((data, row)):
#     def _cleanup(self, ref):
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/attributes.py", line 722, in get
#     value = self.callable_(state, passive)
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/parser/models/sentence.py", line 123, in is_tabular
#     return self.table is not None
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/attributes.py", line 722, in get
#     value = self.callable_(state, passive)
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/utils/data_model_utils/tabular.py", line 35, in same_table
#     for i in range(len(c))
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/utils/udf.py", line 207, in run
#     y = self.apply(doc, **self.apply_kwargs)
# KeyboardInterrupt
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/utils/data_model_utils/tabular.py", line 35, in same_table
#     for i in range(len(c))
# Traceback (most recent call last):
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/strategies.py", line 750, in _load_for_state
#     session, state, primary_key_identity, passive
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/candidates/candidates.py", line 281, in apply
#     for mention in candidate_class.mentions
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/strategies.py", line 750, in _load_for_state
#     session, state, primary_key_identity, passive
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/utils/data_model_utils/tabular.py", line 35, in <genexpr>
#     for i in range(len(c))
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/attributes.py", line 286, in __get__
#     return self.impl.get(instance_state(instance), dict_)
#   File "/usr/local/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/utils/data_model_utils/tabular.py", line 35, in <genexpr>
#     for i in range(len(c))
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/candidates/candidates.py", line 281, in <listcomp>
#     for mention in candidate_class.mentions
#   File "<string>", line 1, in <lambda>
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/parser/models/sentence.py", line 123, in is_tabular
#     return self.table is not None
#   File "<string>", line 1, in <lambda>
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/attributes.py", line 722, in get
#     value = self.callable_(state, passive)
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/utils/udf.py", line 207, in run
#     y = self.apply(doc, **self.apply_kwargs)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/attributes.py", line 286, in __get__
#     return self.impl.get(instance_state(instance), dict_)
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/parser/models/sentence.py", line 123, in is_tabular
#     return self.table is not None
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/attributes.py", line 286, in __get__
#     return self.impl.get(instance_state(instance), dict_)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/strategies.py", line 892, in _emit_lazyload
#     .with_post_criteria(set_default_params)
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/candidates/candidates.py", line 281, in apply
#     for mention in candidate_class.mentions
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/strategies.py", line 717, in _load_for_state
#     session, state, passive
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/strategies.py", line 840, in _emit_lazyload
#     session.query(self.mapper), primary_key_identity
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/attributes.py", line 722, in get
#     value = self.callable_(state, passive)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/attributes.py", line 286, in __get__
#     return self.impl.get(instance_state(instance), dict_)
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/candidates/candidates.py", line 281, in <listcomp>
#     for mention in candidate_class.mentions
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/attributes.py", line 722, in get
#     value = self.callable_(state, passive)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/ext/baked.py", line 544, in all
#     return list(self)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/strategies.py", line 750, in _load_for_state
#     session, state, primary_key_identity, passive
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/ext/baked.py", line 615, in _load_on_pk_identity
#     result = list(bq.for_session(self.session).params(**params))
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/strategies.py", line 765, in _get_ident_for_use_get
#     for pk in self.mapper.primary_key
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/strategies.py", line 717, in _load_for_state
#     session, state, passive
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/attributes.py", line 722, in get
#     value = self.callable_(state, passive)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/attributes.py", line 286, in __get__
#     return self.impl.get(instance_state(instance), dict_)
#   File "<string>", line 1, in <lambda>
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/ext/baked.py", line 439, in __iter__
#     self.session._autoflush()
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/loading.py", line 81, in instances
#     rows = [proc(row) for row in fetch]
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/strategies.py", line 765, in <listcomp>
#     for pk in self.mapper.primary_key
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/strategies.py", line 765, in _get_ident_for_use_get
#     for pk in self.mapper.primary_key
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/strategies.py", line 717, in _load_for_state
#     session, state, passive
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/strategies.py", line 892, in _emit_lazyload
#     .with_post_criteria(set_default_params)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/attributes.py", line 722, in get
#     value = self.callable_(state, passive)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/session.py", line 1591, in _autoflush
#     self.flush()
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/mapper.py", line 2801, in _get_state_attr_by_column
#     return state.manager[prop.key].impl.get(state, dict_, passive=passive)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/strategies.py", line 765, in <listcomp>
#     for pk in self.mapper.primary_key
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/strategies.py", line 765, in _get_ident_for_use_get
#     for pk in self.mapper.primary_key
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/attributes.py", line 717, in get
#     value = state._load_expired(state, passive)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/strategies.py", line 750, in _load_for_state
#     session, state, primary_key_identity, passive
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/session.py", line 2496, in flush
#     self._flush(objects)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/loading.py", line 81, in <listcomp>
#     rows = [proc(row) for row in fetch]
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/ext/baked.py", line 544, in all
#     return list(self)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/mapper.py", line 2801, in _get_state_attr_by_column
#     return state.manager[prop.key].impl.get(state, dict_, passive=passive)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/strategies.py", line 765, in <listcomp>
#     for pk in self.mapper.primary_key
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/state.py", line 652, in _load_expired
#     self.manager.deferred_scalar_loader(self, toload)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/session.py", line 2637, in _flush
#     transaction.rollback(_capture_exception=True)
#   File "<string>", line 1, in <lambda>
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/attributes.py", line 717, in get
#     value = state._load_expired(state, passive)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/loading.py", line 872, in polymorphic_instance
#     _instance = polymorphic_instances[discriminator]
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/ext/baked.py", line 439, in __iter__
#     self.session._autoflush()
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/mapper.py", line 2801, in _get_state_attr_by_column
#     return state.manager[prop.key].impl.get(state, dict_, passive=passive)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py", line 69, in __exit__
#     exc_value, with_traceback=exc_tb,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/loading.py", line 975, in load_scalar_attributes
#     refresh_state=state,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/state.py", line 652, in _load_expired
#     self.manager.deferred_scalar_loader(self, toload)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/strategies.py", line 892, in _emit_lazyload
#     .with_post_criteria(set_default_params)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/util/_collections.py", line 739, in __missing__
#     self[key] = val = self.creator(key)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/session.py", line 1591, in _autoflush
#     self.flush()
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/attributes.py", line 717, in get
#     value = state._load_expired(state, passive)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/util/compat.py", line 178, in raise_
#     raise exception
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/loading.py", line 207, in load_on_ident
#     identity_token=identity_token,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/loading.py", line 975, in load_scalar_attributes
#     refresh_state=state,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/ext/baked.py", line 544, in all
#     return list(self)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/loading.py", line 864, in configure_subclass_mapper
#     _polymorphic_from=mapper,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/state.py", line 652, in _load_expired
#     self.manager.deferred_scalar_loader(self, toload)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/session.py", line 2496, in flush
#     self._flush(objects)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/session.py", line 2597, in _flush
#     flush_context.execute()
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/loading.py", line 287, in load_on_pk_identity
#     return q.one()
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/loading.py", line 207, in load_on_ident
#     identity_token=identity_token,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/ext/baked.py", line 439, in __iter__
#     self.session._autoflush()
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/loading.py", line 975, in load_scalar_attributes
#     refresh_state=state,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/loading.py", line 434, in _instance_processor
#     context, path, mapper, result, adapter, populators
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/session.py", line 2637, in _flush
#     transaction.rollback(_capture_exception=True)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/unitofwork.py", line 422, in execute
#     rec.execute(self)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/query.py", line 3360, in one
#     ret = self.one_or_none()
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/loading.py", line 287, in load_on_pk_identity
#     return q.one()
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/session.py", line 1591, in _autoflush
#     self.flush()
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/loading.py", line 207, in load_on_ident
#     identity_token=identity_token,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/interfaces.py", line 567, in create_row_processor
#     context, path, loader, mapper, result, adapter, populators
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/unitofwork.py", line 589, in execute
#     uow,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py", line 69, in __exit__
#     exc_value, with_traceback=exc_tb,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/query.py", line 3329, in one_or_none
#     ret = list(self)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/query.py", line 3360, in one
#     ret = self.one_or_none()
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/loading.py", line 287, in load_on_pk_identity
#     return q.one()
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/session.py", line 2496, in flush
#     self._flush(objects)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/strategies.py", line 223, in create_row_processor
#     getter = result._getter(col, False)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/persistence.py", line 245, in save_obj
#     insert,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/util/compat.py", line 178, in raise_
#     raise exception
# KeyboardInterrupt
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/query.py", line 3329, in one_or_none
#     ret = list(self)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/query.py", line 3360, in one
#     ret = self.one_or_none()
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/session.py", line 2637, in _flush
#     transaction.rollback(_capture_exception=True)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/persistence.py", line 1136, in _emit_insert_statements
#     statement, params
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/session.py", line 2597, in _flush
#     flush_context.execute()
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/result.py", line 783, in _getter
#     return getter(key, raiseerr)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/query.py", line 3329, in one_or_none
#     ret = list(self)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py", line 69, in __exit__
#     exc_value, with_traceback=exc_tb,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/query.py", line 3405, in __iter__
#     return self._execute_and_instances(context)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 984, in execute
#     return meth(self, multiparams, params)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/unitofwork.py", line 422, in execute
#     rec.execute(self)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/result.py", line 704, in _getter
#     ret = self._key_fallback(key, None, raiseerr)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/query.py", line 3405, in __iter__
#     return self._execute_and_instances(context)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/elements.py", line 293, in _execute_on_connection
#     return connection._execute_clauseelement(self, multiparams, params)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/util/compat.py", line 178, in raise_
#     raise exception
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/unitofwork.py", line 589, in execute
#     uow,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/query.py", line 3430, in _execute_and_instances
#     result = conn.execute(querycontext.statement, self._params)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/result.py", line 645, in _key_fallback
#     if isinstance(key, util.string_types):
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/query.py", line 3430, in _execute_and_instances
#     result = conn.execute(querycontext.statement, self._params)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1103, in _execute_clauseelement
#     distilled_params,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/session.py", line 2597, in _flush
#     flush_context.execute()
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/persistence.py", line 245, in save_obj
#     insert,
# KeyboardInterrupt
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1178, in _execute_context
#     e, util.text_type(statement), parameters, None, None
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 984, in execute
#     return meth(self, multiparams, params)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 984, in execute
#     return meth(self, multiparams, params)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/unitofwork.py", line 422, in execute
#     rec.execute(self)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1485, in _handle_dbapi_exception
#     util.raise_(exc_info[1], with_traceback=exc_info[2])
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/persistence.py", line 1136, in _emit_insert_statements
#     statement, params
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/elements.py", line 293, in _execute_on_connection
#     return connection._execute_clauseelement(self, multiparams, params)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/unitofwork.py", line 589, in execute
#     uow,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/elements.py", line 293, in _execute_on_connection
#     return connection._execute_clauseelement(self, multiparams, params)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/util/compat.py", line 178, in raise_
#     raise exception
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 984, in execute
#     return meth(self, multiparams, params)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1094, in _execute_clauseelement
#     else None,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/persistence.py", line 245, in save_obj
#     insert,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1175, in _execute_context
#     context = constructor(dialect, self, conn, *args)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1094, in _execute_clauseelement
#     else None,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/elements.py", line 293, in _execute_on_connection
#     return connection._execute_clauseelement(self, multiparams, params)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/persistence.py", line 1136, in _emit_insert_statements
#     statement, params
#   File "<string>", line 1, in <lambda>
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/default.py", line 803, in _init_compiled
#     self.cursor = self.create_cursor()
#   File "<string>", line 1, in <lambda>
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1103, in _execute_clauseelement
#     distilled_params,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 984, in execute
#     return meth(self, multiparams, params)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/elements.py", line 468, in compile
#     return self._compiler(dialect, bind=bind, **kw)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/default.py", line 1159, in create_cursor
#     return self._dbapi_connection.cursor()
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/elements.py", line 468, in compile
#     return self._compiler(dialect, bind=bind, **kw)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1288, in _execute_context
#     e, statement, parameters, cursor, context
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/elements.py", line 293, in _execute_on_connection
#     return connection._execute_clauseelement(self, multiparams, params)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/pool/base.py", line 978, in cursor
#     return self.connection.cursor(*args, **kwargs)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/elements.py", line 474, in _compiler
#     return dialect.statement_compiler(dialect, self, **kw)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/elements.py", line 474, in _compiler
#     return dialect.statement_compiler(dialect, self, **kw)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1485, in _handle_dbapi_exception
#     util.raise_(exc_info[1], with_traceback=exc_info[2])
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1103, in _execute_clauseelement
#     distilled_params,
# KeyboardInterrupt
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/compiler.py", line 590, in __init__
#     Compiled.__init__(self, dialect, statement, **kwargs)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/compiler.py", line 590, in __init__
#     Compiled.__init__(self, dialect, statement, **kwargs)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/util/compat.py", line 178, in raise_
#     raise exception
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1288, in _execute_context
#     e, statement, parameters, cursor, context
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/compiler.py", line 319, in __init__
#     self.string = self.process(self.statement, **compile_kwargs)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/compiler.py", line 319, in __init__
#     self.string = self.process(self.statement, **compile_kwargs)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1248, in _execute_context
#     cursor, statement, parameters, context
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1485, in _handle_dbapi_exception
#     util.raise_(exc_info[1], with_traceback=exc_info[2])
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/compiler.py", line 350, in process
#     return obj._compiler_dispatch(self, **kwargs)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/compiler.py", line 350, in process
#     return obj._compiler_dispatch(self, **kwargs)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/default.py", line 590, in do_execute
#     cursor.execute(statement, parameters)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/util/compat.py", line 178, in raise_
#     raise exception
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/visitors.py", line 95, in _compiler_dispatch
#     return meth(self, **kw)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/visitors.py", line 95, in _compiler_dispatch
#     return meth(self, **kw)
#   File "/usr/local/lib/python3.7/encodings/utf_8.py", line 15, in decode
#     def decode(input, errors='strict'):
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1248, in _execute_context
#     cursor, statement, parameters, context
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/compiler.py", line 2137, in visit_select
#     for name, column in select._columns_plus_names
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/compiler.py", line 2137, in visit_select
#     for name, column in select._columns_plus_names
# KeyboardInterrupt
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/compiler.py", line 2137, in <listcomp>
#     for name, column in select._columns_plus_names
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/default.py", line 590, in do_execute
#     cursor.execute(statement, parameters)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/compiler.py", line 2137, in <listcomp>
#     for name, column in select._columns_plus_names
# KeyboardInterrupt
#   File "/usr/local/lib/python3.7/encodings/utf_8.py", line 15, in decode
#     def decode(input, errors='strict'):
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/compiler.py", line 1889, in _label_select_column
#     return result_expr._compiler_dispatch(self, **column_clause_args)
# KeyboardInterrupt
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/visitors.py", line 95, in _compiler_dispatch
#     return meth(self, **kw)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/compiler.py", line 850, in visit_label
#     + self.preparer.format_label(label, labelname)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/visitors.py", line 95, in _compiler_dispatch
#     return meth(self, **kw)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/compiler.py", line 886, in visit_column
#     table = column.table
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/elements.py", line 4056, in _get_table
#     def _get_table(self):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/src/notebooks_as_py/troy200_fonduer.py in <module>
#     277 for i, docs in enumerate([train_docs, dev_docs, test_docs]):
#     278     if (not has_candidates):
# --> 279         candidate_extractor.apply(docs, split=i, parallelism=PARALLEL)
#     280     print(f"Number of Candidates in split={i}: {session.query(RowCandidate).filter(RowCandidate.split == i).count()}")
#     281
#
# ~/.venv/lib/python3.7/site-packages/fonduer/candidates/candidates.py in apply(self, docs, split, clear, parallelism, progress_bar)
#     131             clear=clear,
#     132             parallelism=parallelism,
# --> 133             progress_bar=progress_bar,
#     134         )
#     135
#
# ~/.venv/lib/python3.7/site-packages/fonduer/utils/udf.py in apply(self, doc_loader, clear, parallelism, progress_bar, **kwargs)
#      79         # Use the parallelism of the class if none is provided to apply
#      80         parallelism = parallelism if parallelism else self.parallelism
# ---> 81         self._apply(doc_loader, parallelism, clear=clear, **kwargs)
#      82
#      83         # Close progress bar
#
# ~/.venv/lib/python3.7/site-packages/fonduer/utils/udf.py in _apply(self, doc_loader, parallelism, **kwargs)
#     138         ) and count_parsed < total_count:
#     139             try:
# --> 140                 y = out_queue.get(timeout=1)
#     141                 self._add(y)
#     142                 # Update progress bar whenever an item has been processed
#
# <string> in get(self, *args, **kwds)
#
# /usr/local/lib/python3.7/multiprocessing/managers.py in _callmethod(self, methodname, args, kwds)
#     817
#     818         conn.send((self._id, methodname, args, kwds))
# --> 819         kind, result = conn.recv()
#     820
#     821         if kind == '#RETURN':
#
# /usr/local/lib/python3.7/multiprocessing/connection.py in recv(self)
#     249         self._check_readable()
#     250         buf = self._recv_bytes()
# --> 251         return _ForkingPickler.loads(buf.getbuffer())
#     252
#     253     def poll(self, timeout=0.0):
#
# ~/.venv/lib/python3.7/site-packages/sqlalchemy/orm/state.py in __setstate__(self, state_dict)
#     470         return state_dict
#     471
# --> 472     def __setstate__(self, state_dict):
#     473         inst = state_dict["instance"]
#     474         if inst is not None:
#
# KeyboardInterrupt:
# Process CandidateExtractorUDF-23:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/utils/udf.py", line 207, in run
#     y = self.apply(doc, **self.apply_kwargs)
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/candidates/candidates.py", line 281, in apply
#     for mention in candidate_class.mentions
#   File "/home/user/.venv/lib/python3.7/site-packages/fonduer/candidates/candidates.py", line 281, in <listcomp>
#     for mention in candidate_class.mentions
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/attributes.py", line 286, in __get__
#     return self.impl.get(instance_state(instance), dict_)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/attributes.py", line 722, in get
#     value = self.callable_(state, passive)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/strategies.py", line 750, in _load_for_state
#     session, state, primary_key_identity, passive
#   File "<string>", line 1, in <lambda>
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/strategies.py", line 892, in _emit_lazyload
#     .with_post_criteria(set_default_params)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/ext/baked.py", line 544, in all
#     return list(self)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/ext/baked.py", line 439, in __iter__
#     self.session._autoflush()
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/session.py", line 1591, in _autoflush
#     self.flush()
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/session.py", line 2496, in flush
#     self._flush(objects)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/session.py", line 2637, in _flush
#     transaction.rollback(_capture_exception=True)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py", line 69, in __exit__
#     exc_value, with_traceback=exc_tb,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/util/compat.py", line 178, in raise_
#     raise exception
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/session.py", line 2597, in _flush
#     flush_context.execute()
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/unitofwork.py", line 422, in execute
#     rec.execute(self)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/unitofwork.py", line 589, in execute
#     uow,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/persistence.py", line 245, in save_obj
#     insert,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/orm/persistence.py", line 1136, in _emit_insert_statements
#     statement, params
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 984, in execute
#     return meth(self, multiparams, params)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/sql/elements.py", line 293, in _execute_on_connection
#     return connection._execute_clauseelement(self, multiparams, params)
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1103, in _execute_clauseelement
#     distilled_params,
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1288, in _execute_context
#     e, statement, parameters, cursor, context
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1485, in _handle_dbapi_exception
#     util.raise_(exc_info[1], with_traceback=exc_info[2])
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/util/compat.py", line 178, in raise_
#     raise exception
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1248, in _execute_context
#     cursor, statement, parameters, context
#   File "/home/user/.venv/lib/python3.7/site-packages/sqlalchemy/engine/default.py", line 590, in do_execute
#     cursor.execute(statement, parameters)
#   File "/usr/local/lib/python3.7/encodings/utf_8.py", line 15, in decode
#     def decode(input, errors='strict'):
# KeyboardInterrupt
